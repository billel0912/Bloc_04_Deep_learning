# %% [markdown]
# <img src="https://full-stack-assets.s3.eu-west-3.amazonaws.com/M08-deep-learning/AT%26T_logo_2016.svg" alt="AT&T LOGO" width="30%" />
#
# # SPAM detector:
# ## Spam was the main challenge for AT&T, because it had to manually flag spam for a while. So it looked for a way to automatically identify spam.
#
# ## The goal is to make an automated spam identifier, so it needs to develop a model that can spot spam in the message content.

# %% [markdown]
# <h1> Import librairies <h1>

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import spacy
import plotly.express as px
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# from tensorflow.keras import Sequential
# from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
# from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
# from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix,  ConfusionMatrixDisplay, RocCurveDisplay, classification_report
import sklearn
from sklearn.preprocessing import  OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split

from spacy.lang.en.stop_words import STOP_WORDS
import en_core_web_sm
import os
import io

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## I. Exploring the data :

# %% [markdown]
# #### Upload Data :

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Fullstuck_3/Deep Learning/Projet deep_learning/spam.csv", encoding='ISO-8859-1', error_bad_lines=False)
# Out:
# <ipython-input-4-2baf2f44c1cc>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Fullstuck_3/Deep Learning/Projet deep_learning/spam.csv", encoding='ISO-8859-1', error_bad_lines=False)

# %% [markdown]
# #### Overview and statistics :

# %%
print("Number of rows : {}".format(df.shape[0]))
print()

print("Display of dataset: ")
display(df.head())
print()

print("Basics statistics: ")
display(df.describe(include='all'))
print()

print("Percentage of missing values: ")
display(100 * df.isnull().mean())
# Out:
# Number of rows : 5572
#
# Display of dataset:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
# Basics statistics:
#           v1                      v2  \
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30
#
#                                                Unnamed: 2  \
# count                                                  50
# unique                                                 43
# top      bt not his girlfrnd... G o o d n i g h t . . .@"
# freq                                                    3
#
#                    Unnamed: 3 Unnamed: 4
# count                      12          6
# unique                     10          5
# top      MK17 92H. 450Ppw 16"    GNT:-)"
# freq                        2          2
# Percentage of missing values:
# v1             0.000000
# v2             0.000000
# Unnamed: 2    99.102656
# Unnamed: 3    99.784637
# Unnamed: 4    99.892319
# dtype: float64

# %% [markdown]
# Three columns are useless because they have almost only missing values (Unnamed: 2, Unnamed: 3, Unnamed: 4). The other two columns are the message (v2) and the tag assigned to the message (spam for spam and ham for normal messages). We can be glad that there are no missing values in these two useful columns

# %% [markdown]
# #### Data Cleaning and Display :

# %%
df = df.astype('string')
df = df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'])
df = df.rename(columns={'v1': 'label', 'v2' : 'message'})

# %%
df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
sns.countplot(x = df['label'])
plt.show()

# %% [markdown]
# A positive point is that our feature columns (message) are uniform, composed only of text. We will therefore have to apply preprocessing on the data to be able to use them with our model.

# %%
fig_target =  px.pie(df, values= df['label'].value_counts().values, names=df['label'].value_counts().index, title = 'Label proportion', width = 600, height = 400)
fig_target.update(layout=dict(title=dict(x=0.5)))
fig_target.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4d0b8d28-8ec2-4410-b191-d5f7457f88ec" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d0b8d28-8ec2-4410-b191-d5f7457f88ec")) {                    Plotly.newPlot(                        "4d0b8d28-8ec2-4410-b191-d5f7457f88ec",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["ham","spam"],"legendgroup":"","name":"","showlegend":true,"values":[4825,747],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2 ...

# %% [markdown]
# The data is skewed (imbalanced), but it should still be enough to obtain relevant results.

# %% [markdown]
# #### II. Preprocessing:

# %% [markdown]
# <h4> Keep only the alpha numeric caracters <h4>

# %%
df["message_clean"] = df["message"].apply(lambda x:''.join(ch for ch in x if ch.isalnum() or ch==" " or ch=="'"))
df["message_clean"] = df["message_clean"].apply(lambda x: x.replace(" +"," ").lower().strip())
df.head()
# Out:
#   label                                            message  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                        message_clean
# 0  go until jurong point crazy available only in ...
# 1                            ok lar joking wif u oni
# 2  free entry in 2 a wkly comp to win fa cup fina...
# 3        u dun say so early hor u c already then say
# 4  nah i don't think he goes to usf he lives arou...

# %% [markdown]
# <h4> Lemmatization <h4>

# %%
nlp = spacy.load("en_core_web_sm")
df["message_clean"] = df["message_clean"].apply(lambda x: " ".join([token.lemma_ for token in nlp(x) if (token.lemma_ not in STOP_WORDS) and (token.text not in STOP_WORDS)]))
mask0 = df.message_clean.apply(lambda x: type(x)==str)
df = df[mask0]
mask1 = df['message_clean'].isna()==False
df = df[mask1]
df.head()
# Out:
#   label                                            message  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                        message_clean
# 0  jurong point crazy available bugis n great wor...
# 1                              ok lar joke wif u oni
# 2  free entry 2 wkly comp win fa cup final tkts 2...
# 3                                u dun early hor u c
# 4                                 nah think usf live

# %% [markdown]
# <h4> Tokenization <h4>

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer() # instanciate the tokenizer
tokenizer.fit_on_texts(df.message_clean)
df["message_encoded"] = tokenizer.texts_to_sequences(df.message_clean)

# %%
df.head()
# Out:
#   label                                            message  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                        message_clean  \
# 0  jurong point crazy available bugis n great wor...
# 1                              ok lar joke wif u oni
# 2  free entry 2 wkly comp win fa cup final tkts 2...
# 3                                u dun early hor u c
# 4                                 nah think usf live
#
#                                      message_encoded
# 0  [3605, 229, 446, 463, 941, 31, 49, 203, 942, 7...
# 1                        [7, 194, 464, 288, 1, 1456]
# 2  [10, 299, 2, 532, 661, 29, 1457, 848, 423, 145...
# 3                         [1, 124, 149, 2358, 1, 78]
# 4                                [704, 19, 662, 128]

# %% [markdown]
# <h4> Padding <h4>

# %%
message_pad = tf.keras.preprocessing.sequence.pad_sequences(df["message_encoded"], padding="post")
message_pad
# Out:
# array([[3605,  229,  446, ...,    0,    0,    0],
#        [   7,  194,  464, ...,    0,    0,    0],
#        [  10,  299,    2, ...,    0,    0,    0],
#        ...,
#        [8186,  936, 8187, ...,    0,    0,    0],
#        [ 112, 8188, 1597, ...,    0,    0,    0],
#        [2078,  318,    0, ...,    0,    0,    0]], dtype=int32)

# %%
vocab_size = len(tokenizer.word_index)
print('Vocabulary size :',vocab_size)
df.head()
# Out:
# Vocabulary size : 8188
#   label                                            message  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                        message_clean  \
# 0  jurong point crazy available bugis n great wor...
# 1                              ok lar joke wif u oni
# 2  free entry 2 wkly comp win fa cup final tkts 2...
# 3                                u dun early hor u c
# 4                                 nah think usf live
#
#                                      message_encoded
# 0  [3605, 229, 446, 463, 941, 31, 49, 203, 942, 7...
# 1                        [7, 194, 464, 288, 1, 1456]
# 2  [10, 299, 2, 532, 661, 29, 1457, 848, 423, 145...
# 3                         [1, 124, 149, 2358, 1, 78]
# 4                                [704, 19, 662, 128]

# %% [markdown]
# <h4> Train/Test split <h4>

# %%
xtrain, xval, ytrain, yval = train_test_split(message_pad,df.label, test_size=0.3)

# %% [markdown]
# <h4> Label encoding --> text to numeric <h4>

# %%
encoder = LabelEncoder()
ytrain = encoder.fit_transform(ytrain)
yval = encoder.transform(yval)

# %% [markdown]
# <h4> Batch construction and shuffle <h4>

# %%
train = tf.data.Dataset.from_tensor_slices((xtrain, ytrain))
val = tf.data.Dataset.from_tensor_slices((xval, yval))
train_batch = train.shuffle(len(train)).batch(64)
val_batch = val.shuffle(len(val)).batch(64)

# %% [markdown]
# <h2> III. Model construction <h2>

# %% [markdown]
# #### A. Establishing a baseline

# %%
lr = LogisticRegression(max_iter=1500)
lr.fit(xtrain,ytrain)
pred_logreg = lr.predict(xval)

print(classification_report(yval,pred_logreg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      1444
#            1       0.64      0.27      0.38       228
#
#     accuracy                           0.88      1672
#    macro avg       0.76      0.62      0.65      1672
# weighted avg       0.86      0.88      0.86      1672

# %%
nb = MultinomialNB()
nb.fit(xtrain,ytrain)
nb_pred = nb.predict(xval)

print(classification_report(yval,nb_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.93      1444
#            1       0.53      0.78      0.63       228
#
#     accuracy                           0.88      1672
#    macro avg       0.75      0.84      0.78      1672
# weighted avg       0.90      0.88      0.89      1672

# %% [markdown]
# Logistic regression and Multinomial Naive Bayes are two methods that can be used to identify spam emails. Logistic regression is a basic method that can identify a few spam emails, while Multinomial Naive Bayes can identify more spam emails but also misidentifies more legitimate emails. However, both methods are not very useful in a production environment but can provide a good starting point

# %% [markdown]
# #### B. Simple embedding :

# %%
simple_model = tf.keras.Sequential([
                  # Couche d'Input Word Embedding           
                  tf.keras.layers.Embedding(vocab_size + 1, 8, input_shape=[message_pad.shape[1],],name="embedding"),
                  # Gobal average pooling
                  tf.keras.layers.GlobalAveragePooling1D(),

                  # Couche Dense classique
                  tf.keras.layers.Dense(16, activation='relu'),

                  tf.keras.layers.Dense(1, activation="sigmoid")
])

# %%
optimizer= tf.keras.optimizers.Adam()

simple_model.compile(optimizer=optimizer,
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=tf.keras.metrics.BinaryAccuracy())

# %%
history = simple_model.fit(train_batch, 
                    epochs=40, 
                    validation_data=val_batch)
# Out:
# Epoch 1/40
# 61/61 [==============================] - 15s 134ms/step - loss: 0.6584 - binary_accuracy: 0.8256 - val_loss: 0.6151 - val_binary_accuracy: 0.8636
# Epoch 2/40
# 61/61 [==============================] - 5s 88ms/step - loss: 0.5541 - binary_accuracy: 0.8669 - val_loss: 0.4897 - val_binary_accuracy: 0.8636
# Epoch 3/40
# 61/61 [==============================] - 3s 45ms/step - loss: 0.4304 - binary_accuracy: 0.8669 - val_loss: 0.3905 - val_binary_accuracy: 0.8636
# Epoch 4/40
# 61/61 [==============================] - 3s 45ms/step - loss: 0.3665 - binary_accuracy: 0.8669 - val_loss: 0.3633 - val_binary_accuracy: 0.8636
# Epoch 5/40
# 61/61 [==============================] - 2s 26ms/step - loss: 0.3506 - binary_accuracy: 0.8669 - val_loss: 0.3561 - val_binary_accuracy: 0.8636
# Epoch 6/40
# 61/61 [==============================] - 1s 20ms/step - loss: 0.3430 - binary_accuracy: 0.8669 - val_loss: 0.3499 - val_binary_accuracy: 0.8636
# Epoch 7/40
# 61/61 [==============================] - 1s 23ms/step - loss: 0.3353 - binary_accuracy: 0.8669 - val_loss: 0.3429 - val_binary_accuracy: 0.8636
# Epoch 8/40
# 61/61 [==============================] - 1s 17ms/step - loss: 0.3254 - binary_accuracy: 0.8669 - val_loss: 0.3309 - val_binary_accuracy: 0.8636
# Epoch 9/40
# 61/61 [==============================] - 1s 12ms/step - loss: 0.3074 - binary_accuracy: 0.8669 - val_loss: 0.3121 - val_binary_accuracy: 0.8636
# Epoch 10/40
# 61/61 [==============================] - 1s 15ms/step - loss: 0.2831 - binary_accuracy: 0.8669 - val_loss: 0.2866 - val_binary_accuracy: 0.8636
# Epoch 11/40
# 61/61 [==============================] - 1s 12ms/step - loss: 0.2491 - binary_accuracy: 0.8685 - val_loss: 0.2478 - val_binary_accuracy: 0.8684
# Epoch 12/40
# 61/61 [==============================] - 1s 20ms/step - loss: 0.2007 - binary_accuracy: 0.8982 - val_loss: 0.2027 - val_binary_accuracy: 0.9103
# Epoch 13/40
# 61/61 [==============================] - 0s 4ms/step - loss: 0.1535 - binary_accuracy: 0.9482 - val_loss: 0.1630 - val_binary_accuracy: 0.9372
# Epoch 14/40
# 61/61 [==============================] - 1s 10ms/step - loss: 0.1171 - binary_accuracy: 0.9644 - val_loss: 0.1342 - val_binary_accuracy: 0.9516
# Epoch 15/40
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0925 - binary_accuracy: 0.9736 - val_loss: 0.1151 - val_binary_accuracy: 0.9611
# Epoch 16/40
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0764 - binary_accuracy: 0.9797 - val_loss: 0.1009 - val_binary_accuracy: 0.9731
# Epoch 17/40
# 61/61 [==============================] - 1s 9ms/step - loss: 0.0647 - binary_accuracy: 0.9823 - val_loss: 0.0928 - val_binary_accuracy: 0.9731
# Epoch 18/40
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0563 - binary_accuracy: 0.9833 - val_loss: 0.0852 - val_binary_accuracy: 0.9731
# Epoch 19/40
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0497 - binary_accuracy: 0.9851 - val_loss: 0.0794 - val_binary_accuracy: 0.9755
# Epoch 20/40
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0447 - binary_accuracy: 0.9867 - val_loss: 0.0753 - val_binary_accuracy: 0.9773
# Epoch 21/40
# 61/61 [==============================] - 1s 9ms/step - loss: 0.0404 - binary_accuracy: 0.9882 - val_loss: 0.0726 - val_binary_accuracy: 0.9773
# Epoch 22/40
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0369 - binary_accuracy: 0.9892 - val_loss: 0.0698 - val_binary_accuracy: 0.9785
# Epoch 23/40
# 61/61 [==============================] - 1s 9ms/step - loss: 0.0340 - binary_accuracy: 0.9905 - val_loss: 0.0686 - val_binary_accuracy: 0.9785
# Epoch 24/40
# 61/61 [==============================] - 1s 10ms/step - loss: 0.0314 - binary_accuracy: 0.9903 - val_loss: 0.0709 - val_binary_accuracy: 0.9779
# Epoch 25/40
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0285 - binary_accuracy: 0.9913 - val_loss: 0.0639 - val_binary_accuracy: 0.9803
# Epoch 26/40
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0267 - binary_accuracy: 0.9915 - val_loss: 0.0627 - val_binary_accuracy: 0.9803
# Epoch 27/40
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0247 - binary_accuracy: 0.9923 - val_loss: 0.0625 - val_binary_accuracy: 0.9803
# Epoch 28/40
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0229 - binary_accuracy: 0.9928 - val_loss: 0.0618 - val_binary_accuracy: 0.9809
# Epoch 29/40
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0216 - binary_accuracy: 0.9933 - val_loss: 0.0585 - val_binary_accuracy: 0.9815
# Epoch 30/40
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0201 - binary_accuracy: 0.9944 - val_loss: 0.0571 - val_binary_accuracy: 0.9839
# Epoch 31/40
# 61/61 [==============================] - 1s 9ms/step - loss: 0.0188 - binary_accuracy: 0.9949 - val_loss: 0.0610 - val_binary_accuracy: 0.9809
# Epoch 32/40
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0178 - binary_accuracy: 0.9944 - val_loss: 0.0588 - val_binary_accuracy: 0.9821
# Epoch 33/40
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0165 - binary_accuracy: 0.9951 - val_loss: 0.0557 - val_binary_accuracy: 0.9839
# Epoch 34/40
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0154 - binary_accuracy: 0.9956 - val_loss: 0.0568 - val_binary_accuracy: 0.9839
# Epoch 35/40
# 61/61 [==============================] - 1s 9ms/step - loss: 0.0145 - binary_accuracy: 0.9954 - val_loss: 0.0545 - val_binary_accuracy: 0.9844
# Epoch 36/40
# 61/61 [==============================] - 1s 9ms/step - loss: 0.0135 - binary_accuracy: 0.9959 - val_loss: 0.0562 - val_binary_accuracy: 0.9839
# Epoch 37/40
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0126 - binary_accuracy: 0.9962 - val_loss: 0.0550 - val_binary_accuracy: 0.9839
# Epoch 38/40
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0121 - binary_accuracy: 0.9962 - val_loss: 0.0538 - val_binary_accuracy: 0.9839
# Epoch 39/40
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0112 - binary_accuracy: 0.9969 - val_loss: 0.0597 - val_binary_accuracy: 0.9839
# Epoch 40/40
# 61/61 [==============================] - 1s 9ms/step - loss: 0.0106 - binary_accuracy: 0.9969 - val_loss: 0.0566 - val_binary_accuracy: 0.9839

# %%
from plotly import graph_objects as go
color_chart = ["#4B9AC7", "#4BE8E0", "#9DD4F3", "#97FBF6", "#2A7FAF", "#23B1AB", "#0E3449", "#015955"]
fig = go.Figure(data=[
                      go.Scatter(
                          y=history.history["loss"],
                          name="Training loss",
                          mode="lines",
                          marker=dict(
                              color=color_chart[0]
                          )),
                      go.Scatter(
                          y=history.history["val_loss"],
                          name="Validation loss",
                          mode="lines",
                          marker=dict(
                              color=color_chart[1]
                          ))
])
fig.update_layout(
    title='Training and val loss across epochs',
    xaxis_title='epochs',
    yaxis_title='Cross Entropy'    
)
fig.update(layout=dict(title=dict(x=0.5)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e5579bdc-1369-476a-ab9e-abe738d2f48a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5579bdc-1369-476a-ab9e-abe738d2f48a")) {                    Plotly.newPlot(                        "e5579bdc-1369-476a-ab9e-abe738d2f48a",                        [{"marker":{"color":"#4B9AC7"},"mode":"lines","name":"Training loss","y":[0.6583916544914246,0.5540679693222046,0.43041133880615234,0.3664926290512085,0.35057640075683594,0.3430047631263733,0.3353477418422699,0.3254386782646179,0.30743247270584106,0.2831496000289917,0.24905835092067719,0.20072101056575775,0.15346994996070862,0.11705400794744492,0.092477947473526,0.07640323042869568,0.06472667306661606,0.05630757659673691,0.04972907528281212,0.0447075217962265,0.040421053767204285,0.03686510771512985,0.034003663808107376,0.03136352077126503,0.02852628380060196,0.026705386117100716,0.024661162868142128,0.022878454998135567,0.02161058597266674,0.020119430497288704,0.018770895898342133,0.017787015065550804,0.016453562304377556,0.015379351563751698,0.014491614885628223,0.013519753701984882,0.012644315138459206,0.012098006904125214,0.011170516721904278,0.01058703102171421],"type":"scatter"},{"marker":{"color":"#4BE8E0"},"mode":"lines","name":"Validation loss","y":[0.6151341795921326,0.489679753780365,0.39051416516304016,0.3632602095603943,0.3560694754123688,0.34985432028770447,0.34291768074035645,0.33092382550239563,0.3120732009410858,0.2865593731403351,0.24779388308525085,0.202662855386734,0.1630038619041443,0.13416706025600433,0.11506056785583496,0.1008862778544426,0.09277725964784622,0.08516678214073181,0.07944215834140778,0.07528170198202133,0.07264282554388046,0.06977259367704391,0.06861463189125061,0.07086516171693802,0.06389842182397842,0.06265874952077866,0.06245548278093338,0.06182492524385452,0.058450523763895035,0.05708121880888939,0.06104500964283943,0.05883895978331566,0.0556705966591835,0.05681649222970009,0.05445033684372902,0.05620887875556946,0.05497546121478081,0.05376671627163887,0.05968629568815231,0.05662674084305763],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colo ...

# %%
fig = go.Figure(data=[
                      go.Scatter(
                          y=history.history["binary_accuracy"],
                          name="Training accuracy",
                          mode="lines",
                          marker=dict(
                              color=color_chart[0]
                          )),
                      go.Scatter(
                          y=history.history["val_binary_accuracy"],
                          name="Validation accuracy",
                          mode="lines",
                          marker=dict(
                              color=color_chart[1]
                          ))
])
fig.update_layout(
    title='Training and val accuracy across epochs',
    xaxis_title='epochs',
    yaxis_title='Accuracy'    
)
fig.update(layout=dict(title=dict(x=0.5)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9bef53fa-64a1-4806-89d0-392ea426a715" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9bef53fa-64a1-4806-89d0-392ea426a715")) {                    Plotly.newPlot(                        "9bef53fa-64a1-4806-89d0-392ea426a715",                        [{"marker":{"color":"#4B9AC7"},"mode":"lines","name":"Training accuracy","y":[0.8256410360336304,0.8669230937957764,0.8669230937957764,0.8669230937957764,0.8669230937957764,0.8669230937957764,0.8669230937957764,0.8669230937957764,0.8669230937957764,0.8669230937957764,0.868461549282074,0.8982051014900208,0.9482051134109497,0.9643589854240417,0.9735897183418274,0.9797435998916626,0.9823076725006104,0.9833333492279053,0.9851282238960266,0.9866666793823242,0.9882051348686218,0.989230751991272,0.9905128479003906,0.9902564287185669,0.991282045841217,0.9915384650230408,0.9923076629638672,0.9928205013275146,0.9933333396911621,0.9943589568138123,0.9948717951774597,0.9943589568138123,0.9951282143592834,0.9956410527229309,0.9953846335411072,0.9958974123001099,0.9961538314819336,0.9961538314819336,0.9969230890274048,0.9969230890274048],"type":"scatter"},{"marker":{"color":"#4BE8E0"},"mode":"lines","name":"Validation accuracy","y":[0.8636363744735718,0.8636363744735718,0.8636363744735718,0.8636363744735718,0.8636363744735718,0.8636363744735718,0.8636363744735718,0.8636363744735718,0.8636363744735718,0.8636363744735718,0.8684210777282715,0.910287082195282,0.9372009634971619,0.9515550136566162,0.9611244201660156,0.9730861186981201,0.9730861186981201,0.9730861186981201,0.97547847032547,0.9772727489471436,0.9772727489471436,0.9784688949584961,0.9784688949584961,0.9778708219528198,0.9802631735801697,0.9802631735801697,0.9802631735801697,0.980861246585846,0.9814593195915222,0.9838516712188721,0.980861246585846,0.9820573925971985,0.9838516712188721,0.9838516712188721,0.9844497442245483,0.9838516712188721,0.9838516712188721,0.9838516712188721,0.9838516712188721,0.9838516712188721],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorb ...

# %% [markdown]
# The baseline model’s accuracy improved rapidly, reaching an accuracy score of around 0.983 before plateauing. Let’s now check the F1-score since we suspected high false negatives due to the imbalance

# %%
Y_train_pred = simple_model.predict(xtrain)
Y_test_pred = simple_model.predict(xval)
Y_train_pred = Y_train_pred.reshape(-1)
Y_test_pred = Y_test_pred.reshape(-1)
Y_train_pred= pd.DataFrame(Y_train_pred)
Y_test_pred= pd.DataFrame(Y_test_pred)
Y_train_pred = round(Y_train_pred)
Y_test_pred = round(Y_test_pred)
print("f1-score on training set : ", f1_score(ytrain, Y_train_pred))
print("f1-score on test set : ", f1_score(yval, Y_test_pred))
# Out:
# 122/122 [==============================] - 0s 1ms/step
# 53/53 [==============================] - 0s 1ms/step
# f1-score on training set :  0.9892891918208374
# f1-score on test set :  0.9370629370629371

# %%
Confusion_matrix_train = confusion_matrix(ytrain,Y_train_pred)
ConfusionMatrixDisplay(Confusion_matrix_train).plot()
print('Confusion Matrix for the train set:')
plt.show()
Confusion_matrix_test = confusion_matrix(yval,Y_test_pred)
print('Confusion Matrix for the test set:')
ConfusionMatrixDisplay(Confusion_matrix_test).plot()
plt.show()
# Out:
# Confusion Matrix for the train set:
# Confusion Matrix for the test set:

# %%
predictions_1 = simple_model.predict(xval)
predictions_1 = predictions_1.reshape(-1)
results_1 = pd.DataFrame({'test':yval,'pred':predictions_1})
results_1['pred'] = round(results_1['pred'])
print(classification_report(results_1.test,results_1.pred))
# Out:
# 53/53 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1444
#            1       1.00      0.88      0.94       228
#
#     accuracy                           0.98      1672
#    macro avg       0.99      0.94      0.96      1672
# weighted avg       0.98      0.98      0.98      1672

# %% [markdown]
# #### C. LSTM model :

# %%
LSTM_model = tf.keras.Sequential([
    # Couche d'Input Word Embedding
    tf.keras.layers.Embedding(vocab_size + 1, 300, input_shape=[message_pad.shape[1],],name="embedding"),
    # Couche LSTM
    tf.keras.layers.LSTM(64,dropout=0.2, recurrent_dropout=0.2),
    # Couche Dense classique
    tf.keras.layers.Dense(1, activation="sigmoid")
])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
LSTM_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 74, 300)           2456700
#
#  lstm (LSTM)                 (None, 64)                93440
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,550,205
# Trainable params: 2,550,205
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer= tf.keras.optimizers.Adam(learning_rate = 0.00007)

LSTM_model.compile(optimizer=optimizer,
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=tf.keras.metrics.BinaryAccuracy())

# %%
history = LSTM_model.fit(train_batch, 
                    epochs=40, 
                    validation_data=val_batch)
# Out:
# Epoch 1/40
# 61/61 [==============================] - 26s 372ms/step - loss: 0.6041 - binary_accuracy: 0.8285 - val_loss: 0.4921 - val_binary_accuracy: 0.8636
# Epoch 2/40
# 61/61 [==============================] - 20s 327ms/step - loss: 0.4128 - binary_accuracy: 0.8669 - val_loss: 0.3987 - val_binary_accuracy: 0.8636
# Epoch 3/40
# 61/61 [==============================] - 17s 277ms/step - loss: 0.3925 - binary_accuracy: 0.8669 - val_loss: 0.3981 - val_binary_accuracy: 0.8636
# Epoch 4/40
# 61/61 [==============================] - 17s 268ms/step - loss: 0.3922 - binary_accuracy: 0.8669 - val_loss: 0.3980 - val_binary_accuracy: 0.8636
# Epoch 5/40
# 61/61 [==============================] - 16s 266ms/step - loss: 0.3926 - binary_accuracy: 0.8669 - val_loss: 0.3973 - val_binary_accuracy: 0.8636
# Epoch 6/40
# 61/61 [==============================] - 15s 251ms/step - loss: 0.3921 - binary_accuracy: 0.8669 - val_loss: 0.3968 - val_binary_accuracy: 0.8636
# Epoch 7/40
# 61/61 [==============================] - 15s 250ms/step - loss: 0.3919 - binary_accuracy: 0.8669 - val_loss: 0.3973 - val_binary_accuracy: 0.8636
# Epoch 8/40
# 61/61 [==============================] - 15s 244ms/step - loss: 0.3893 - binary_accuracy: 0.8669 - val_loss: 0.3939 - val_binary_accuracy: 0.8636
# Epoch 9/40
# 61/61 [==============================] - 15s 248ms/step - loss: 0.3709 - binary_accuracy: 0.8669 - val_loss: 0.2971 - val_binary_accuracy: 0.8636
# Epoch 10/40
# 61/61 [==============================] - 15s 250ms/step - loss: 0.1568 - binary_accuracy: 0.9405 - val_loss: 0.1270 - val_binary_accuracy: 0.9647
# Epoch 11/40
# 61/61 [==============================] - 15s 249ms/step - loss: 0.1053 - binary_accuracy: 0.9787 - val_loss: 0.1037 - val_binary_accuracy: 0.9785
# Epoch 12/40
# 61/61 [==============================] - 15s 241ms/step - loss: 0.0982 - binary_accuracy: 0.9849 - val_loss: 0.1140 - val_binary_accuracy: 0.9791
# Epoch 13/40
# 61/61 [==============================] - 15s 244ms/step - loss: 0.0759 - binary_accuracy: 0.9885 - val_loss: 0.1192 - val_binary_accuracy: 0.9779
# Epoch 14/40
# 61/61 [==============================] - 15s 236ms/step - loss: 0.0744 - binary_accuracy: 0.9885 - val_loss: 0.1100 - val_binary_accuracy: 0.9791
# Epoch 15/40
# 61/61 [==============================] - 15s 246ms/step - loss: 0.0629 - binary_accuracy: 0.9903 - val_loss: 0.0994 - val_binary_accuracy: 0.9809
# Epoch 16/40
# 61/61 [==============================] - 14s 236ms/step - loss: 0.0592 - binary_accuracy: 0.9905 - val_loss: 0.0930 - val_binary_accuracy: 0.9821
# Epoch 17/40
# 61/61 [==============================] - 15s 252ms/step - loss: 0.0534 - binary_accuracy: 0.9915 - val_loss: 0.0920 - val_binary_accuracy: 0.9821
# Epoch 18/40
# 61/61 [==============================] - 15s 238ms/step - loss: 0.0707 - binary_accuracy: 0.9877 - val_loss: 0.1186 - val_binary_accuracy: 0.9767
# Epoch 19/40
# 61/61 [==============================] - 14s 237ms/step - loss: 0.0667 - binary_accuracy: 0.9885 - val_loss: 0.1138 - val_binary_accuracy: 0.9773
# Epoch 20/40
# 61/61 [==============================] - 14s 234ms/step - loss: 0.0636 - binary_accuracy: 0.9890 - val_loss: 0.1106 - val_binary_accuracy: 0.9779
# Epoch 21/40
# 61/61 [==============================] - 15s 241ms/step - loss: 0.0629 - binary_accuracy: 0.9890 - val_loss: 0.1104 - val_binary_accuracy: 0.9779
# Epoch 22/40
# 61/61 [==============================] - 15s 239ms/step - loss: 0.0595 - binary_accuracy: 0.9897 - val_loss: 0.1102 - val_binary_accuracy: 0.9779
# Epoch 23/40
# 61/61 [==============================] - 15s 245ms/step - loss: 0.0581 - binary_accuracy: 0.9900 - val_loss: 0.1102 - val_binary_accuracy: 0.9779
# Epoch 24/40
# 61/61 [==============================] - 15s 246ms/step - loss: 0.0574 - binary_accuracy: 0.9900 - val_loss: 0.1106 - val_binary_accuracy: 0.9779
# Epoch 25/40
# 61/61 [==============================] - 15s 239ms/step - loss: 0.0582 - binary_accuracy: 0.9897 - val_loss: 0.1105 - val_binary_accuracy: 0.9779
# Epoch 26/40
# 61/61 [==============================] - 15s 240ms/step - loss: 0.0573 - binary_accuracy: 0.9900 - val_loss: 0.1108 - val_binary_accuracy: 0.9779
# Epoch 27/40
# 61/61 [==============================] - 15s 239ms/step - loss: 0.0560 - binary_accuracy: 0.9903 - val_loss: 0.1106 - val_binary_accuracy: 0.9779
# Epoch 28/40
# 61/61 [==============================] - 14s 236ms/step - loss: 0.0548 - binary_accuracy: 0.9905 - val_loss: 0.1105 - val_binary_accuracy: 0.9779
# Epoch 29/40
# 61/61 [==============================] - 14s 238ms/step - loss: 0.0545 - binary_accuracy: 0.9905 - val_loss: 0.1108 - val_binary_accuracy: 0.9779
# Epoch 30/40
# 61/61 [==============================] - 15s 244ms/step - loss: 0.0554 - binary_accuracy: 0.9903 - val_loss: 0.1107 - val_binary_accuracy: 0.9779
# Epoch 31/40
# 61/61 [==============================] - 14s 235ms/step - loss: 0.0530 - binary_accuracy: 0.9908 - val_loss: 0.1111 - val_binary_accuracy: 0.9779
# Epoch 32/40
# 61/61 [==============================] - 15s 239ms/step - loss: 0.0491 - binary_accuracy: 0.9915 - val_loss: 0.0949 - val_binary_accuracy: 0.9815
# Epoch 33/40
# 61/61 [==============================] - 15s 242ms/step - loss: 0.0456 - binary_accuracy: 0.9923 - val_loss: 0.0956 - val_binary_accuracy: 0.9815
# Epoch 34/40
# 61/61 [==============================] - 14s 238ms/step - loss: 0.0418 - binary_accuracy: 0.9931 - val_loss: 0.0961 - val_binary_accuracy: 0.9815
# Epoch 35/40
# 61/61 [==============================] - 14s 237ms/step - loss: 0.0465 - binary_accuracy: 0.9921 - val_loss: 0.0965 - val_binary_accuracy: 0.9815
# Epoch 36/40
# 61/61 [==============================] - 14s 236ms/step - loss: 0.0405 - binary_accuracy: 0.9933 - val_loss: 0.0941 - val_binary_accuracy: 0.9821
# Epoch 37/40
# 61/61 [==============================] - 14s 237ms/step - loss: 0.0428 - binary_accuracy: 0.9928 - val_loss: 0.0944 - val_binary_accuracy: 0.9821
# Epoch 38/40
# 61/61 [==============================] - 14s 237ms/step - loss: 0.0426 - binary_accuracy: 0.9928 - val_loss: 0.0972 - val_binary_accuracy: 0.9815
# Epoch 39/40
# 61/61 [==============================] - 14s 234ms/step - loss: 0.0415 - binary_accuracy: 0.9931 - val_loss: 0.0976 - val_binary_accuracy: 0.9815
# Epoch 40/40
# 61/61 [==============================] - 14s 236ms/step - loss: 0.0413 - binary_accuracy: 0.9931 - val_loss: 0.0977 - val_binary_accuracy: 0.9815

# %% [markdown]
# The model trains really fast and additional epochs don’t improve performance; it’s already very high!

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(y=history.history["loss"],
                    mode='lines',
                    name='loss'))
fig.add_trace(go.Scatter(y=history.history["val_loss"],
                    mode='lines',
                    name='val_loss'))
fig.update_layout(
    title='Training and val loss across epochs',
    xaxis_title='epochs',
    yaxis_title='Cross Entropy' )
fig.update(layout=dict(title=dict(x=0.5)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b6b77abb-9073-4d72-a29e-c4f12a19b799" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6b77abb-9073-4d72-a29e-c4f12a19b799")) {                    Plotly.newPlot(                        "b6b77abb-9073-4d72-a29e-c4f12a19b799",                        [{"mode":"lines","name":"loss","y":[0.604101300239563,0.41277191042900085,0.39252927899360657,0.3921717703342438,0.3926340341567993,0.3921467959880829,0.3918873071670532,0.3893013596534729,0.37092429399490356,0.1568295657634735,0.10529808700084686,0.09821940958499908,0.07594114542007446,0.07436864823102951,0.06286390870809555,0.059164755046367645,0.05340875685214996,0.07072349637746811,0.06665491312742233,0.06361309438943863,0.06290946155786514,0.05945856124162674,0.05810070410370827,0.05740872025489807,0.05824638530611992,0.057329244911670685,0.05599503591656685,0.054843757301568985,0.05446373298764229,0.055417679250240326,0.05297591909766197,0.0491386242210865,0.045607246458530426,0.04177271947264671,0.04654286429286003,0.040544379502534866,0.042799245566129684,0.0426054447889328,0.04150068387389183,0.04129159823060036],"type":"scatter"},{"mode":"lines","name":"val_loss","y":[0.4920841157436371,0.39865660667419434,0.3981080949306488,0.39800816774368286,0.3972686231136322,0.3967916667461395,0.3972901403903961,0.3939189016819,0.29708850383758545,0.12702450156211853,0.1036892756819725,0.11403912305831909,0.11918440461158752,0.1100274845957756,0.09939931333065033,0.09298863261938095,0.09195861965417862,0.11862197518348694,0.11375939100980759,0.1106213629245758,0.1103513315320015,0.11018781363964081,0.11024337261915207,0.11061101406812668,0.11047716438770294,0.1107516959309578,0.11060039699077606,0.11046811938285828,0.11079220473766327,0.11069030314683914,0.1110718846321106,0.09485570341348648,0.09564950317144394,0.09606342017650604,0.0965133085846901,0.09411273151636124,0.09443121403455734,0.09723012894392014,0.09758260101079941,0.09765838831663132],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outline ...

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(y=history.history["binary_accuracy"],
                    mode='lines',
                    name='Training accuracy'))
fig.add_trace(go.Scatter(y=history.history["val_binary_accuracy"],
                    mode='lines',
                    name='Validation accuracy'))
fig.update_layout(
    title='Training and val accuracy across epochs',
    xaxis_title='epochs',
    yaxis_title='Accuracy' )
fig.update(layout=dict(title=dict(x=0.5)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="cca1b100-d7a9-438d-b4df-4f227a5d66e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cca1b100-d7a9-438d-b4df-4f227a5d66e3")) {                    Plotly.newPlot(                        "cca1b100-d7a9-438d-b4df-4f227a5d66e3",                        [{"mode":"lines","name":"Training accuracy","y":[0.8284615278244019,0.8669230937957764,0.8669230937957764,0.8669230937957764,0.8669230937957764,0.8669230937957764,0.8669230937957764,0.8669230937957764,0.8669230937957764,0.9405128359794617,0.9787179231643677,0.9848718047142029,0.9884615540504456,0.9884615540504456,0.9902564287185669,0.9905128479003906,0.9915384650230408,0.9876922965049744,0.9884615540504456,0.9889743328094482,0.9889743328094482,0.9897435903549194,0.9900000095367432,0.9900000095367432,0.9897435903549194,0.9900000095367432,0.9902564287185669,0.9905128479003906,0.9905128479003906,0.9902564287185669,0.9907692074775696,0.9915384650230408,0.9923076629638672,0.9930769205093384,0.9920513033866882,0.9933333396911621,0.9928205013275146,0.9928205013275146,0.9930769205093384,0.9930769205093384],"type":"scatter"},{"mode":"lines","name":"Validation accuracy","y":[0.8636363744735718,0.8636363744735718,0.8636363744735718,0.8636363744735718,0.8636363744735718,0.8636363744735718,0.8636363744735718,0.8636363744735718,0.8636363744735718,0.964712917804718,0.9784688949584961,0.9790669679641724,0.9778708219528198,0.9790669679641724,0.980861246585846,0.9820573925971985,0.9820573925971985,0.9766746163368225,0.9772727489471436,0.9778708219528198,0.9778708219528198,0.9778708219528198,0.9778708219528198,0.9778708219528198,0.9778708219528198,0.9778708219528198,0.9778708219528198,0.9778708219528198,0.9778708219528198,0.9778708219528198,0.9778708219528198,0.9814593195915222,0.9814593195915222,0.9814593195915222,0.9814593195915222,0.9820573925971985,0.9820573925971985,0.9814593195915222,0.9814593195915222,0.9814593195915222],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0 ...

# %%
Y_train_pred = LSTM_model.predict(xtrain)
Y_test_pred = LSTM_model.predict(xval)
Y_train_pred = Y_train_pred.reshape(-1)
Y_test_pred = Y_test_pred.reshape(-1)
Y_train_pred= pd.DataFrame(Y_train_pred)
Y_test_pred= pd.DataFrame(Y_test_pred)
Y_train_pred = round(Y_train_pred)
Y_test_pred = round(Y_test_pred)
print("f1-score on training set : ", f1_score(ytrain, Y_train_pred))
print("f1-score on test set : ", f1_score(yval, Y_test_pred))
# Out:
# 122/122 [==============================] - 3s 24ms/step
# 53/53 [==============================] - 1s 24ms/step
# f1-score on training set :  0.9765166340508806
# f1-score on test set :  0.9293849658314352

# %%
Confusion_matrix_train = confusion_matrix(ytrain,Y_train_pred)
ConfusionMatrixDisplay(Confusion_matrix_train).plot()
print('Confusion Matrix for the train set:')
plt.show()
Confusion_matrix_test = confusion_matrix(yval,Y_test_pred)
print('Confusion Matrix for the test set:')
ConfusionMatrixDisplay(Confusion_matrix_test).plot()
plt.show()
# Out:
# Confusion Matrix for the train set:
# Confusion Matrix for the test set:

# %%
predictions_2 = LSTM_model.predict(xval)
predictions_2 = predictions_2.reshape(-1)
results_2 = pd.DataFrame({'test':yval,'pred':predictions_2})
results_2['pred'] = round(results_2['pred'])
print(classification_report(results_2.test,results_2.pred))
# Out:
# 53/53 [==============================] - 1s 24ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1444
#            1       0.97      0.89      0.93       228
#
#     accuracy                           0.98      1672
#    macro avg       0.98      0.94      0.96      1672
# weighted avg       0.98      0.98      0.98      1672

# %% [markdown]
# #### <h4> IV. Transfer Learning: <h4>

# %% [markdown]
# Roberta :

# %%
df["message_clean"] = df["message"].apply(lambda x:''.join(ch for ch in x if ch.isalnum() or ch==" " or ch=="'"))
df["message_clean"] = df["message_clean"].apply(lambda x: x.replace(" +"," ").lower().strip())
xtrain0, xval0, ytrain0, yval0 = train_test_split(df.message_clean,df.label, test_size=0.2, stratify=df.label)
ytrain0 = encoder.fit_transform(ytrain0)
yval0 = encoder.transform(yval0)

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.3-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 54.0 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 96.0 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.3 tokenizers-0.13.2 transformers-4.27.3

# %%
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained('mariagrandury/roberta-base-finetuned-sms-spam-detection')
model = TFAutoModelForSequenceClassification.from_pretrained('mariagrandury/roberta-base-finetuned-sms-spam-detection',from_pt=True)
# Reference : https://huggingface.co/mariagrandury/roberta-base-finetuned-sms-spam-detection

encoded_input = tokenizer(list(xval0), return_tensors='tf', padding = True)
output = model(encoded_input)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/735 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaForSequenceClassification: ['roberta.embeddings.position_ids']
# - This IS expected if you are initializing TFRobertaForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFRobertaForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.

# %%
output_binary = [np.argmax(x) for x in output[0]]
print("accuracy on test set : ", accuracy_score(yval0, output_binary))
print("f1-score on test set : ", f1_score(yval0, output_binary))
# Out:
# accuracy on test set :  0.9910313901345291
# f1-score on test set :  0.9657534246575343

# %%
Confusion_matrix_test = confusion_matrix(yval0, output_binary)
print('Confusion Matrix for the test set:')
ConfusionMatrixDisplay(Confusion_matrix_test).plot()
plt.show()
# Out:
# Confusion Matrix for the test set:

# %%
output
# Out:
# TFSequenceClassifierOutput(loss=None, logits=<tf.Tensor: shape=(1115, 2), dtype=float32, numpy=
# array([[ 4.1339126, -3.902228 ],
#        [ 4.394977 , -4.1780987],
#        [ 4.352918 , -4.0802   ],
#        ...,
#        [ 4.2726097, -4.0850134],
#        [ 4.330271 , -4.0733943],
#        [ 4.382277 , -4.176748 ]], dtype=float32)>, hidden_states=None, attentions=None)

# %%
roberta_res = [np.argmax(x) for x in output[0]]
results_3 = pd.DataFrame({'test':yval0,'pred':roberta_res})
print(classification_report(results_3.test,results_3.pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       966
#            1       0.99      0.95      0.97       149
#
#     accuracy                           0.99      1115
#    macro avg       0.99      0.97      0.98      1115
# weighted avg       0.99      0.99      0.99      1115

# %% [markdown]
# #### VI. Conclusion :

# %%
baseline_model_results = classification_report(yval,pred_logreg, output_dict=True)
model_nb_results = classification_report(yval,nb_pred, output_dict=True)
model_1_results = classification_report(results_1.test,results_1.pred, output_dict=True)
model_2_results = classification_report(results_2.test,results_2.pred, output_dict=True)
model_3_results = classification_report(results_3.test,results_3.pred, output_dict=True)
  
total_results = pd.DataFrame({'Logistic Regression':baseline_model_results['1'],
                            'Multinomial Naive Bayes':model_nb_results['1'],
                             'Simple embedding':model_1_results['1'],
                             'LSTM Model':model_2_results['1'],
                             'RoBERTa spam detection':model_3_results['1']}).transpose()

accuracy = [accuracy_score(yval, pred_logreg),
            accuracy_score(yval, nb_pred),
            accuracy_score(results_1.test, results_1.pred),
            accuracy_score(results_2.test, results_2.pred),
            accuracy_score(results_3.test, results_3.pred)]
total_results['Accuracy'] = accuracy

total_results.drop(columns=['support'])
# Out:
#                          precision    recall  f1-score  Accuracy
# Logistic Regression       0.635417  0.267544  0.376543  0.879187
# Multinomial Naive Bayes   0.534535  0.780702  0.634581  0.877392
# Simple embedding          1.000000  0.881579  0.937063  0.983852
# LSTM Model                0.966825  0.894737  0.929385  0.981459
# RoBERTa spam detection    0.986014  0.946309  0.965753  0.991031

# %% [markdown]
# RoBERTa, which is a more advanced model that has undergone extensive training, proved to be the most effective at filtering spam messages as despite the imbalance of the dataset and we have been able to reach an accuracy of 0.99% . <br>
# To improve further, we could combine our results with a list of phone numbers already identified as spam-senders to eliminate the few remaining spams, and/or try to identify other behavioral patterns not contained in the text
